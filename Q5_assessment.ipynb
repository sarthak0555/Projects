# %%
#A

# %%
# Load the csv data
csv_data = pd.read_csv('/Users/sarthakchawla/Downloads/Q5datacsv.csv')

# %%
csv_data
# Out:
#            x
# 0        217
# 1         25
# 2         69
# 3        279
# 4        433
# ...      ...
# 1060895  125
# 1060896  612
# 1060897  106
# 1060898  734
# 1060899    2
#
# [1060900 rows x 1 columns]

# %%
# Retrieve the value at position 1,048,576 (1,048,576 - 1 for zero-based indexing)
value_at_position_csv = csv_data.iloc[1048575].to_dict()

value_at_position_csv
# Out:
# {'x': 133}

# %%
#B

# %%
import pandas as pd

# %%
# Load the TSV file
file_path = '/Users/sarthakchawla/Downloads/tsv.tsv'
tsv_data = pd.read_csv(file_path, sep='\t')

# %%
tsv_data
# Out:
#            x
# 0        817
# 1        823
# 2        228
# 3        590
# 4        238
# ...      ...
# 1060895  887
# 1060896  599
# 1060897  968
# 1060898  712
# 1060899  743
#
# [1060900 rows x 1 columns]

# %%
# Retrieve the value at position 1,048,576 (1,048,576 - 1 for zero-based indexing)
value_at_position_tsv = tsv_data.iloc[1048575].to_dict()

value_at_position_tsv
# Out:
# {'x': 19}

# %%
#C

# %%
import json

# %%
# Load the json file
file_path = '/Users/sarthakchawla/Downloads/json.json'
with open(file_path, 'r') as file:
    json_data = json.load(file)

# %%
json_data
# Out:
# [{'x': 380},
#  {'x': 811},
#  {'x': 660},
#  {'x': 1},
#  {'x': 285},
#  {'x': 794},
#  {'x': 749},
#  {'x': 378},
#  {'x': 894},
#  {'x': 498},
#  {'x': 78},
#  {'x': 332},
#  {'x': 719},
#  {'x': 364},
#  {'x': 967},
#  {'x': 374},
#  {'x': 229},
#  {'x': 398},
#  {'x': 106},
#  {'x': 668},
#  {'x': 557},
#  {'x': 196},
#  {'x': 909},
#  {'x': 568},
#  {'x': 220},
#  {'x': 173},
#  {'x': 914},
#  {'x': 924},
#  {'x': 733},
#  {'x': 914},
#  {'x': 271},
#  {'x': 341},
#  {'x': 324},
#  {'x': 43},
#  {'x': 161},
#  {'x': 943},
#  {'x': 722},
#  {'x': 532},
#  {'x': 429},
#  {'x': 152},
#  {'x': 446},
#  {'x': 361},
#  {'x': 361},
#  {'x': 639},
#  {'x': 397},
#  {'x': 745},
#  {'x': 191},
#  {'x': 237},
#  {'x': 910},
#  {'x': 785},
#  {'x': 503},
#  {'x': 77},
#  {'x': 487},
#  {'x': 576},
#  {'x': 603},
#  {'x': 884},
#  {'x': 244},
#  {'x': 904},
#  {'x': 461},
#  {'x': 957},
#  {'x': 292},
#  {'x': 687},
#  {'x': 33},
#  {'x': 829},
#  {'x': 437},
#  {'x': 824},
#  {'x': 468},
# ...

# %%
# Retrieve the value at position 1,048,576 
value_at_position_json = json_data[1048576]

value_at_position_json
# Out:
# {'x': 572}
